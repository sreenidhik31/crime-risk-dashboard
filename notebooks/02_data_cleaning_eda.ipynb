# %%
import pandas as pd

df = pd.read_csv("data/processed/crime_cleaned.csv")

sample_df = df.sample(
    20000,
    random_state=42
)

sample_df.to_csv(
    "data/processed/crime_sample.csv",
    index=False
)

print(sample_df.shape)
